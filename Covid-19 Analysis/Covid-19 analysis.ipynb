# %% [markdown]
# # Covid-19 Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pip install -U kaleido
# Out:
# Requirement already up-to-date: kaleido in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\asus\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
files=os.listdir(r'E:\Udemy projects\Covid-19')
files
# Out:
# ['country_wise_latest.csv',
#  'covid_19_clean_complete.csv',
#  'day_wise.csv',
#  'full_grouped.csv',
#  'usa_country_wise.csv',
#  'worldometer_data.csv']

# %% [markdown]
# # Function to read all the csv files

# %%
def read_data(path,filename):
    return pd.read_csv(path+'/'+filename)

# %%
path=r'E:\Udemy projects\Covid-19'
world_data=read_data(path,'worldometer_data.csv')

# %%
province_data=read_data(path,'covid_19_clean_complete.csv')

# %%
day_wise=read_data(path,'day_wise.csv')

# %%
grouped_data=read_data(path,'full_grouped.csv')

# %%
usa_data=read_data(path,'usa_country_wise.csv')

# %%
province_data.shape
# Out:
# (49068, 10)

# %% [markdown]
# # Which Country has maximum Total cases, Deaths, Recovered & Active cases

# %%
world_data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
world_data.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
import plotly.express as px

# %%
columns=['TotalCases','TotalDeaths','TotalRecovered','ActiveCases']
for i in columns:
    fig=px.treemap(world_data.iloc[0:20],values=i,path=['Country/Region'],title="Tree Representation of countries according to {}".format(i))
    fig.show("svg")

# %%
day_wise.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %% [markdown]
# # What is the trend of Confirmed, Deaths, Recovered and Active cases

# %%
day_wise.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
fig=px.line(day_wise,x='Date',y=['Confirmed', 'Deaths', 'Recovered', 'Active'],title="Covid cases w.r.t Dates",template='plotly_dark')
fig.show("svg")

# %% [markdown]
# # BarPlot Representation of CoronaViruses Cases w.r.t Time

# %%
world_data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
world_data.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region'],
#       dtype='object')

# %%
fig=px.bar(world_data.iloc[0:20],x='Country/Region',y=['Serious,Critical','TotalDeaths','TotalRecovered','TotalCases','ActiveCases'])
fig.show("svg")

# %% [markdown]
# # Top 20 countries of Total Confirmed Cases, Total Recovered Cases, Total Deaths,Total Active Cases

# %% [markdown]
# Total Confirmed Cases-

# %%
fig=px.bar(world_data.iloc[0:20],y='Country/Region',x='TotalCases',color='TotalCases',text='TotalCases')
fig.update_layout(template='plotly_dark',title_text='Top 20 countries of total confirmed cases')
fig.show("svg")

# %% [markdown]
# Total Death cases-

# %%
world_data.sort_values(by='TotalDeaths',ascending=False)
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 5                   Mexico  North America  1.290662e+08      462690    6590.0
# 11                      UK         Europe  6.792203e+07      308134       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# ..                     ...            ...           ...         ...       ...
# 202  Saint Kitts and Nevis  North America  5.323700e+04          17       NaN
# 203              Greenland  North America  5.678000e+04          14       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
#
# ...

# %%
fig=px.bar(world_data.sort_values(by='TotalDeaths',ascending=False)[0:20],y='Country/Region',x='TotalDeaths',color='TotalDeaths',text='TotalDeaths')
fig.update_layout(template='plotly_dark',title_text='Top 20 countries of total deaths cases')
fig.show("svg")

# %% [markdown]
# Total Active Cases-

# %%
world_data.sort_values(by='ActiveCases',ascending=False)
# Out:
#     Country/Region      Continent    Population  TotalCases  NewCases  \
# 0              USA  North America  3.311981e+08     5032179       NaN
# 1           Brazil  South America  2.127107e+08     2917562       NaN
# 2            India           Asia  1.381345e+09     2025409       NaN
# 3           Russia         Europe  1.459409e+08      871894       NaN
# 8         Colombia  South America  5.093626e+07      357710       NaN
# ..             ...            ...           ...         ...       ...
# 157     San Marino         Europe  3.393800e+04         699       NaN
# 9            Spain         Europe  4.675665e+07      354530       NaN
# 11              UK         Europe  6.792203e+07      308134       NaN
# 29          Sweden         Europe  1.010560e+07       81967       NaN
# 40     Netherlands         Europe  1.713876e+07       56982       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# ...

# %%
fig=px.bar(world_data.sort_values(by='ActiveCases',ascending=False)[0:20],y='Country/Region',x='ActiveCases',color='ActiveCases',text='ActiveCases')
fig.update_layout(template='plotly_dark',title_text='Top 20 countries of active cases')
fig.show("svg")

# %% [markdown]
# Total Recovered Cases-

# %%
fig=px.bar(world_data.sort_values(by='TotalRecovered',ascending=False)[0:20],y='Country/Region',x='TotalRecovered',color='TotalRecovered',text='TotalRecovered')
fig.update_layout(template='plotly_dark',title_text='Top 20 countries of total recovered cases')
fig.show("svg")

# %% [markdown]
# # Pie chart Representation of stats of worst affected countries

# %% [markdown]
# Pie Charts in Donut Shape

# %%
world_data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
labels=world_data[0:15]['Country/Region'].values
cases=['TotalCases','TotalDeaths','TotalRecovered','ActiveCases']
for i in cases:
    fig=px.pie(world_data[0:15],values=i,names=labels,hole=0.3,title=" {} recorded w.r.t to WHO region of 15 worst affected countries".format(i))
    fig.show("svg")

# %% [markdown]
# # Deaths to Confirmed ratio

# %%
world_data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
deaths_to_confirm=world_data['TotalDeaths']/world_data['TotalCases']
deaths_to_confirm
# Out:
# 0      0.032353
# 1      0.033810
# 2      0.020558
# 3      0.016752
# 4      0.017845
#          ...
# 204    0.076923
# 205         NaN
# 206         NaN
# 207         NaN
# 208    0.100000
# Length: 209, dtype: float64

# %%
fig=px.bar(world_data,x='Country/Region',y=deaths_to_confirm,title='Deaths to confirmed ratio of worst affected countries')
fig.show("svg")

# %% [markdown]
# # Deaths to Recovered ratio

# %%
deaths_to_recovered=world_data['TotalDeaths']/world_data['TotalRecovered']
deaths_to_recovered
# Out:
# 0      0.063184
# 1      0.048174
# 2      0.030230
# 3      0.021595
# 4      0.024796
#          ...
# 204    0.100000
# 205         NaN
# 206         NaN
# 207         NaN
# 208    0.125000
# Length: 209, dtype: float64

# %%
fig=px.bar(world_data,x='Country/Region',y=deaths_to_recovered,title='Deaths to recovered ratio of worst affected countries')
fig.show("svg")

# %% [markdown]
# # Tests to Confirmed ratio

# %%
deaths_to_test=world_data['TotalTests']/world_data['TotalCases']
deaths_to_test
# Out:
# 0       12.547170
# 1        4.526446
# 2       10.935742
# 3       34.083165
# 4        5.852658
#           ...
# 204      4.692308
# 205     32.615385
# 206    139.692308
# 207           NaN
# 208           NaN
# Length: 209, dtype: float64

# %%
fig=px.bar(world_data,x='Country/Region',y=deaths_to_test,title='Tests to confirmed ratio of worst affected countries')
fig.show("svg")

# %% [markdown]
# # Serious to Death ratio

# %%
serious_to_death=world_data['Serious,Critical']/world_data['TotalDeaths']
serious_to_death
# Out:
# 0      0.112381
# 1      0.084323
# 2      0.214804
# 3      0.157470
# 4      0.056122
#          ...
# 204         NaN
# 205         NaN
# 206         NaN
# 207         NaN
# 208         NaN
# Length: 209, dtype: float64

# %%
fig=px.bar(world_data,x='Country/Region',y=serious_to_death,title='Serious to death ratio of worst affected countries')
fig.show("svg")

# %% [markdown]
# # Function to get all the statistics related to a country

# %%
world_data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
grouped_data.head()
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
def country_visual(df,country):
    data=df[df['Country/Region']==country]
    data2=data.loc[:,['Date','Confirmed','Deaths','Recovered','Active']]
    
    fig=make_subplots(rows=1,cols=4,subplot_titles=('Confirmed','Deaths','Recovered','Active'))
    
    #With respect to Confirmed
    fig.add_trace(
    go.Scatter(name='Confirmed',x=data2['Date'],y=data2['Confirmed']),row=1,col=1
    )
    
    #With respect to Deaths
    fig.add_trace(
    go.Scatter(name='Deaths',x=data2['Date'],y=data2['Deaths']),row=1,col=2
    )
    
    #With respect to Recovered
    fig.add_trace(
    go.Scatter(name='Recovered',x=data2['Date'],y=data2['Recovered']),row=1,col=3
    )
    
    #With respect to Active
    fig.add_trace(
    go.Scatter(name='Active',x=data2['Date'],y=data2['Active']),row=1,col=4
    )  
    
    fig.update_layout(height=600,width=1000,title_text='Date vs Recorded cases of {}'.format(country),template='plotly_dark')
    fig.show("svg")

# %%
country_visual(grouped_data,'India')

# %%
country_visual(grouped_data,'Brazil')
